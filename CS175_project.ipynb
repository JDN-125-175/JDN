# %%
# ONLY RUN IF NOT SAVED TO GOOGLE DRIVE
# !git clone https://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@github.com/JDN-125-175/JDN.git

# %%
# DISREGARD
# %cd JDN

# %%
# !ls

# %%
# CONNECT TO GOOGLE DRIVE
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# ONLY RUN IF NOT ALREADY SAVED TO GOOGLE DRIVE (AKA ONLY RUN ONCE)
# !git clone https://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@github.com/JDN-125-175/JDN.git
# Out:
# Cloning into 'JDN'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 163 (delta 80), reused 122 (delta 40), pack-reused 0 (from 0)
# Receiving objects: 100% (163/163), 35.32 KiB | 2.94 MiB/s, done.
# Resolving deltas: 100% (80/80), done.

# %%
# %cd JDN
# Out:
# /content/drive/MyDrive/JDN

# %%
# DOUBLE CHECK IT IS THE CORRECT DIR
# !ls
# Out:
# data	  preds_finetuned.txt	__pycache__  src
# data.zip  preds_pretrained.txt	README.txt   t5_spider_ckpt

# %%
# %cd src
# !ls
# Out:
# /content/drive/MyDrive/JDN/src
# evaluate.py		 infer_picard.py      infer.py	    __pycache__
# generate_predictions.py  infer_pretrained.py  load_data.py  train.py

# %%
# %cd /content/drive/MyDrive/JDN
# Out:
# /content/drive/MyDrive/JDN

# %%
# ONCE YOU COMMIT ON GIT ADD, COMMIT, AND PUSH ON GITHUB, RUN THIS CELL THEN RUN WHATEVER FUNCTION CALL BELOW
# !git pull
# Out:
# Already up to date.

# %%
# DRAG DATA.ZIP INTO THE JDN FOLDER ON THE LEFT SIDE, WAIT FOR IT TO LOAD IN, THEN RUN THIS CELL
#!unzip data.zip
# Out:
# Archive:  data.zip
#    creating: data/
#    creating: data/spider/
#   inflating: data/spider/.DS_Store
#    creating: data/spider/database/
#    creating: data/spider/database/academic/
#   inflating: data/spider/database/academic/academic.sqlite
#   inflating: data/spider/database/academic/schema.sql
#    creating: data/spider/database/activity_1/
#   inflating: data/spider/database/activity_1/activity_1.sqlite
#   inflating: data/spider/database/activity_1/schema.sql
#    creating: data/spider/database/aircraft/
#   inflating: data/spider/database/aircraft/aircraft.sqlite
#   inflating: data/spider/database/aircraft/schema.sql
#    creating: data/spider/database/allergy_1/
#   inflating: data/spider/database/allergy_1/allergy_1.sqlite
#   inflating: data/spider/database/allergy_1/schema.sql
#    creating: data/spider/database/apartment_rentals/
#   inflating: data/spider/database/apartment_rentals/apartment_rentals.sqlite
# ...

# %%
# TRAINS MODEL (ETA DEPENDS ON # EPOCHS, 5 EPOCHS ON T4 ~ 25 MINUTES)
# !python src/train.py
# Out:
# ...
# tokenizer_config.json: 2.32kB [00:00, 6.35MB/s]
# spiece.model: 100% 792k/792k [00:00<00:00, 5.19MB/s]
# tokenizer.json: 1.39MB [00:00, 10.1MB/s]
# config.json: 1.21kB [00:00, 4.54MB/s]
# model.safetensors: 100% 242M/242M [00:01<00:00, 170MB/s]
# Loading weights: 100% 131/131 [00:00<00:00, 3272.43it/s, Materializing param=shared.weight]
# generation_config.json: 100% 147/147 [00:00<00:00, 859kB/s]
# epoch 1/7 step 0 loss 6.7289
# epoch 1/7 step 50 loss 2.7398
# epoch 1/7 step 100 loss 3.5082
# epoch 1/7 step 150 loss 2.5440
# epoch 1/7 step 200 loss 2.8274
# epoch 1/7 step 250 loss 2.0360
# epoch 1/7 step 300 loss 2.3837
# epoch 1/7 step 350 loss 2.1316
# epoch 1/7 step 400 loss 2.5981
# epoch 1/7 step 450 loss 1.2533
# epoch 1/7 step 500 loss 1.1814
# epoch 1/7 step 550 loss 1.6945
# epoch 1/7 step 600 loss 1.2164
# epoch 1/7 step 650 loss 2.7068
# epoch 1/7 step 700 loss 1.5811
# epoch 1/7 step 750 loss 1.0758
# epoch 1/7 step 800 loss 1.1522
# epoch 1/7 step 850 loss 1.2939
# ...

# %%
# !python src/generate_predictions.py
# Out:
# Loading weights: 100% 131/131 [00:00<00:00, 1031.56it/s, Materializing param=shared.weight]
# Fine-tuned: 0/1034
# Fine-tuned: 10/1034
# Fine-tuned: 20/1034
# Fine-tuned: 30/1034
# Fine-tuned: 40/1034
# Fine-tuned: 50/1034
# Fine-tuned: 60/1034
# Fine-tuned: 70/1034
# Fine-tuned: 80/1034
# Fine-tuned: 90/1034
# Fine-tuned: 100/1034
# Fine-tuned: 110/1034
# Fine-tuned: 120/1034
# Fine-tuned: 130/1034
# Fine-tuned: 140/1034
# Fine-tuned: 150/1034
# Fine-tuned: 160/1034
# Fine-tuned: 170/1034
# Fine-tuned: 180/1034
# Fine-tuned: 190/1034
# Fine-tuned: 200/1034
# Fine-tuned: 210/1034
# Fine-tuned: 220/1034
# Fine-tuned: 230/1034
# Fine-tuned: 240/1034
# Fine-tuned: 250/1034
# Fine-tuned: 260/1034
# Fine-tuned: 270/1034
# Fine-tuned: 280/1034
# Fine-tuned: 290/1034
# Fine-tuned: 300/1034
# Fine-tuned: 310/1034
# Fine-tuned: 320/1034
# Fine-tuned: 330/1034
# Fine-tuned: 340/1034
# Fine-tuned: 350/1034
# Fine-tuned: 360/1034
# Fine-tuned: 370/1034
# Fine-tuned: 380/1034
# ...

# %%
# !python src/evaluate.py --pred preds_finetuned.txt --split dev --max 0
# Out:
# ...
# Execution accuracy: 0.2437 (252/1034)
# ...
#
# Outcome Breakdown:
#   Correct           :  252/1034 (24.4%)
#   Wrong answer      :  356/1034 (34.4%)  (ran but wrong result)
#   Failed to execute :  426/1034 (41.2%)  (invalid SQL)
#
# Error Statistics:
#   Pred SQL execution errors: 426/1034 (41.20%)
#   Gold SQL execution errors: 2/1034 (0.19%) (check DBs)
#
# Similarity Statistics (for queries that executed successfully):
#   Average Jaccard similarity: 0.4526
#   Perfect matches (similarity=1.0): 257/608
#   High similarity (>=0.8): 262/608
#   Medium similarity (0.5-0.8): 14/608
#   Low similarity (<0.5): 332/608
#
# Pred SQL Error Breakdown:
#   Schema Error: 377 (88.5% of pred errors)
#   Syntax Error: 29 (6.8% of pred errors)
#   Operational Error: 20 (4.7% of pred errors)
#
# Gold SQL Error Breakdown:
#   Operational Error: 2 (100.0% of gold errors)
#
# Breakdown by Difficulty:
#                    Correct   Wrong Ans  Failed SQL   Total
# ...

# %%
# !python src/evaluate.py --pred preds_pretrained.txt --split dev --max 0
# Out:
# ...
# Execution accuracy: 0.5948 (615/1034)
# ...
#
# Outcome Breakdown:
#   Correct           :  615/1034 (59.5%)
#   Wrong answer      :  228/1034 (22.1%)  (ran but wrong result)
#   Failed to execute :  191/1034 (18.5%)  (invalid SQL)
#
# Error Statistics:
#   Pred SQL execution errors: 191/1034 (18.47%)
#   Gold SQL execution errors: 2/1034 (0.19%) (check DBs)
#
# Similarity Statistics (for queries that executed successfully):
#   Average Jaccard similarity: 0.7674
#   Perfect matches (similarity=1.0): 631/843
#   High similarity (>=0.8): 636/843
#   Medium similarity (0.5-0.8): 11/843
#   Low similarity (<0.5): 196/843
#
# Pred SQL Error Breakdown:
#   Schema Error: 169 (88.5% of pred errors)
#   Syntax Error: 15 (7.9% of pred errors)
#   Operational Error: 7 (3.7% of pred errors)
#
# Gold SQL Error Breakdown:
#   Operational Error: 2 (100.0% of gold errors)
#
# Breakdown by Difficulty:
#                    Correct   Wrong Ans  Failed SQL   Total
# ...

# %%
# EVALUATES THE ACROSS ALL EXAMPLES (ETA 9 MINUTES ON T4)
# !python evaluate.py --max 0 --split dev --debug 5
